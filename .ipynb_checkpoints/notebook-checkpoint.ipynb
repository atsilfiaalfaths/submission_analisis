# %% [markdown]
# # PROYEK ANALISIS DATA BIKE RENTAL DATASET

# %% [markdown]
# + NAMA : ATSILFIA ALFATH SYAM
# + USERNAME DICODING : atsilfiaalfaths
# + EMAIL : atsilfiaalfath@gmail.com

# %% [markdown]
# # Pertanyaan Bisnis
# + Bagaimana pengaruh musim (season) dari tahun 2011 sampai 2012 terhadap jumlah penyewa?
# + Bagaimana pengaruh cuaca (weathersit) terhadap jumlah pengguna?
# + Rata-rata pengendara bersepeda paling tinggi pada waktu kapan?
# + aapakah terjadi peningkatan tren rental sepeda dari tahun 2011 ke 2012?
# + Bagaimana pengaruh temp, atemp, hum, windspeed pada tren rental sepeda?
# + bagaimana pengaruh musim terhadap penyewa berdasarkan pelanggan casual dan registered?

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
import calendar

# %% [markdown]
# ## LOAD DATA

# %% [markdown]
# ### load table day

# %%
day_df = pd.read_csv("data/day.csv")
day_df.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %% [markdown]
# ### load table hour

# %%
hour_df = pd.read_csv("data/hour.csv")
hour_df.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %% [markdown]
# ##ACCESING DATA

# %% [markdown]
# ###1. info type data day_df

# %%
day_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    object
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.5+ KB

# %% [markdown]
# ###2. Cek apakah ada missing data

# %%
day_df.isna().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
dapat dilihat bahwa tabel day_df tidak ada missing value

# %% [markdown]
# ###3. cek duplikasi

# %%
print("Jumlah duplikasi data: ", day_df.duplicated().sum())
# Out:
# Jumlah duplikasi data:  0

# %% [markdown]
# pada kolom dteday diubah tipe data menjadi datetime

# %%
day_df.describe()
# Out:
#           instant      season          yr        mnth     holiday     weekday  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean   366.000000    2.496580    0.500684    6.519836    0.028728    2.997264
# std    211.165812    1.110807    0.500342    3.451913    0.167155    2.004787
# min      1.000000    1.000000    0.000000    1.000000    0.000000    0.000000
# 25%    183.500000    2.000000    0.000000    4.000000    0.000000    1.000000
# 50%    366.000000    3.000000    1.000000    7.000000    0.000000    3.000000
# 75%    548.500000    3.000000    1.000000   10.000000    0.000000    5.000000
# max    731.000000    4.000000    1.000000   12.000000    1.000000    6.000000
#
#        workingday  weathersit        temp       atemp         hum   windspeed  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean     0.683995    1.395349    0.495385    0.474354    0.627894    0.190486
# std      0.465233    0.544894    0.183051    0.162961    0.142429    0.077498
# min      0.000000    1.000000    0.059130    0.079070    0.000000    0.022392
# 25%      0.000000    1.000000    0.337083    0.337842    0.520000    0.134950
# 50%      1.000000    1.000000    0.498333    0.486733    0.626667    0.180975
# 75%      1.000000    2.000000    0.655417    0.608602    0.730209    0.233214
# max      1.000000    3.000000    0.861667    0.840896    0.972500    0.507463
#
#             casual   registered          cnt
# count   731.000000   731.000000   731.000000
# mean    848.176471  3656.172367  4504.348837
# std     686.622488  1560.256377  1937.211452
# min       2.000000    20.000000    22.000000
# 25%     315.500000  2497.000000  3152.000000
# 50%     713.000000  3662.000000  4548.000000
# 75%    1096.000000  4776.500000  5956.000000
# max    3410.000000  6946.000000  8714.000000

# %% [markdown]
# dapat diperhatikan pada data diatas, avg total user 4504, dengan min penyewa 22 dalam sehari, dan maksimal 8714

# %% [markdown]
# ## Menilai hour_df

# %% [markdown]
# ### 1. cek type data hour_df

# %%
hour_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  object
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: float64(4), int64(12), object(1)
# memory usage: 2.3+ MB

# %% [markdown]
# *Ada column yang tidak sesuai tipe datanya yaitu kolom dteday yang seharusnya menjadi datetime*

# %% [markdown]
# ### 2. cek ada data kosong

# %%
hour_df.isna().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %% [markdown]
# *tidak ada data yang kosong*

# %%
hour_df.describe()
# Out:
#           instant        season            yr          mnth            hr  \
# count  17379.0000  17379.000000  17379.000000  17379.000000  17379.000000
# mean    8690.0000      2.501640      0.502561      6.537775     11.546752
# std     5017.0295      1.106918      0.500008      3.438776      6.914405
# min        1.0000      1.000000      0.000000      1.000000      0.000000
# 25%     4345.5000      2.000000      0.000000      4.000000      6.000000
# 50%     8690.0000      3.000000      1.000000      7.000000     12.000000
# 75%    13034.5000      3.000000      1.000000     10.000000     18.000000
# max    17379.0000      4.000000      1.000000     12.000000     23.000000
#
#             holiday       weekday    workingday    weathersit          temp  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.028770      3.003683      0.682721      1.425283      0.496987
# std        0.167165      2.005771      0.465431      0.639357      0.192556
# min        0.000000      0.000000      0.000000      1.000000      0.020000
# 25%        0.000000      1.000000      0.000000      1.000000      0.340000
# 50%        0.000000      3.000000      1.000000      1.000000      0.500000
# 75%        0.000000      5.000000      1.000000      2.000000      0.660000
# max        1.000000      6.000000      1.000000      4.000000      1.000000
#
#               atemp           hum     windspeed        casual    registered  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.475775      0.627229      0.190098     35.676218    153.786869
# std        0.171850      0.192930      0.122340     49.305030    151.357286
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.333300      0.480000      0.104500      4.000000     34.000000
# 50%        0.484800      0.630000      0.194000     17.000000    115.000000
# 75%        0.621200      0.780000      0.253700     48.000000    220.000000
# max        1.000000      1.000000      0.850700    367.000000    886.000000
#
#                 cnt
# count  17379.000000
# mean     189.463088
# std      181.387599
# min        1.000000
# 25%       40.000000
# 50%      142.000000
# 75%      281.000000
# max      977.000000

# %% [markdown]
# ### 3. cek ada data duplikasi

# %%
print("Jumlah duplikasi data: ", hour_df.duplicated().sum())
# Out:
# Jumlah duplikasi data:  0

# %%
*Tidak Data duplikasi pada hour_df  *

# %%
day_df.nunique()
# Out:
# instant       731
# dteday        731
# season          4
# yr              2
# mnth           12
# holiday         2
# weekday         7
# workingday      2
# weathersit      3
# temp          499
# atemp         690
# hum           595
# windspeed     650
# casual        606
# registered    679
# cnt           696
# dtype: int64

# %%
# day_df dapat dikategorykan berdasarkan data tersebut, namun pada kolom weathersit hanya terdapat 3 musim

# %%
hour_df.nunique()
# Out:
# instant       17379
# dteday          731
# season            4
# yr                2
# mnth             12
# hr               24
# holiday           2
# weekday           7
# workingday        2
# weathersit        4
# temp             50
# atemp            65
# hum              89
# windspeed        30
# casual          322
# registered      776
# cnt             869
# dtype: int64

# %% [markdown]
# *pedoman kategory hour_df, pada weathersit terdapat 4 kategori*. data ini berbeda dengan day_df yang hanya memiliki 3 weathersit
#
#
# jika ditelaah lebih dalam, ditemukan weathersit kategori 4 pada hour_df pada waktu:

# %% [markdown]
# + 26/01/2011 pada hr :16
# + 09/01/2012 pada hr : 18
# + 21/01/2012 pada hr : 1

# %%
hour_df.describe()
# Out:
#           instant        season            yr          mnth            hr  \
# count  17379.0000  17379.000000  17379.000000  17379.000000  17379.000000
# mean    8690.0000      2.501640      0.502561      6.537775     11.546752
# std     5017.0295      1.106918      0.500008      3.438776      6.914405
# min        1.0000      1.000000      0.000000      1.000000      0.000000
# 25%     4345.5000      2.000000      0.000000      4.000000      6.000000
# 50%     8690.0000      3.000000      1.000000      7.000000     12.000000
# 75%    13034.5000      3.000000      1.000000     10.000000     18.000000
# max    17379.0000      4.000000      1.000000     12.000000     23.000000
#
#             holiday       weekday    workingday    weathersit          temp  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.028770      3.003683      0.682721      1.425283      0.496987
# std        0.167165      2.005771      0.465431      0.639357      0.192556
# min        0.000000      0.000000      0.000000      1.000000      0.020000
# 25%        0.000000      1.000000      0.000000      1.000000      0.340000
# 50%        0.000000      3.000000      1.000000      1.000000      0.500000
# 75%        0.000000      5.000000      1.000000      2.000000      0.660000
# max        1.000000      6.000000      1.000000      4.000000      1.000000
#
#               atemp           hum     windspeed        casual    registered  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.475775      0.627229      0.190098     35.676218    153.786869
# std        0.171850      0.192930      0.122340     49.305030    151.357286
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.333300      0.480000      0.104500      4.000000     34.000000
# 50%        0.484800      0.630000      0.194000     17.000000    115.000000
# 75%        0.621200      0.780000      0.253700     48.000000    220.000000
# max        1.000000      1.000000      0.850700    367.000000    886.000000
#
#                 cnt
# count  17379.000000
# mean     189.463088
# std      181.387599
# min        1.000000
# 25%       40.000000
# 50%      142.000000
# 75%      281.000000
# max      977.000000

# %% [markdown]
# ## CLEANING DATA

# %% [markdown]
# #### 1. Memperbaiki data day_df kolom tdatey

# %%
datetime_columns = ["dteday"]

for column in datetime_columns:
  day_df[column] = pd.to_datetime(day_df[column])

# %%
day_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    datetime64[ns]
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: datetime64[ns](1), float64(4), int64(11)
# memory usage: 91.5 KB

# %% [markdown]
# *Kolom datetime telah diperbaiki data typenya*

# %% [markdown]
# ### 2. Memperbaiki tipe data hour_df

# %% [markdown]
# *karena terdapat kesalahan tipe data pada kolom dteday ,maka tipe data dteday diperbaiki menjadi datetime*

# %%
datetime_columns = ["dteday"]

for column in datetime_columns:
  hour_df[column] = pd.to_datetime(hour_df[column])

# %%
hour_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  datetime64[ns]
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: datetime64[ns](1), float64(4), int64(12)
# memory usage: 2.3 MB

# %% [markdown]
# *nah sudah berhasil memperbaiki tipe data dteday*

# %%
#Rename kolom agar tidak menimbulkan keliru pembacaan tabel

day_df.rename(columns={
    'dteday': 'dateday',
    'yr': 'year',
    'mnth': 'month',
    'cnt': 'total_count_user'
}, inplace=True)

day_df.head()
# Out:
#    instant    dateday  season  year  month  holiday  weekday  workingday  \
# 0        1 2011-01-01       1     0      1        0        6           0
# 1        2 2011-01-02       1     0      1        0        0           0
# 2        3 2011-01-03       1     0      1        0        1           1
# 3        4 2011-01-04       1     0      1        0        2           1
# 4        5 2011-01-05       1     0      1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#    total_count_user
# 0               985
# 1               801
# 2              1349
# 3              1562
# 4              1600

# %%
# tambah kolom day name untuk dari index weekday, ini berfungsi untuk memudahkan sort value. dan tetap tidak menghapus weekday
weekday_mapping = {
    0: 'Sunday',
    1: 'Monday',
    2: 'Tuesday',
    3: 'Wednesday',
    4: 'Thursday',
    5: 'Friday',
    6: 'Saturday'
}
day_df['day_name'] = day_df['weekday'].apply(lambda x: weekday_mapping[x])

# %%
day_df.sample(5)
# Out:
#      instant    dateday  season  year  month  holiday  weekday  workingday  \
# 613      614 2012-09-05       3     1      9        0        3           1
# 513      514 2012-05-28       2     1      5        1        1           0
# 686      687 2012-11-17       4     1     11        0        6           0
# 363      364 2011-12-30       1     0     12        0        5           1
# 603      604 2012-08-26       3     1      8        0        0           0
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 613           1  0.736667  0.708983  0.741250   0.187808     832        6280
# 513           1  0.712500  0.679300  0.676250   0.196521    2557        3486
# 686           1  0.325000  0.326383  0.545417   0.179729    1313        4316
# 363           1  0.311667  0.318812  0.636667   0.134337     491        2508
# 603           2  0.653333  0.595996  0.845833   0.228858    1483        3772
#
#      total_count_user   day_name
# 613              7112  Wednesday
# 513              6043     Monday
# 686              5629   Saturday
# 363              2999     Friday
# 603              5255     Sunday

# %%
# Mengubah kategori angka ke keterangan pada kolom year, month, season, weekday, weathersit

day_df['year'] = day_df['year'].map({
    0: 2011,
    1: 2012,
})
day_df['month'] = day_df['month'].map({
    1: 'Jan', 2: 'Feb', 3: 'Mar', 4: 'Apr', 5: 'May', 6: 'Jun',
    7: 'Jul', 8: 'Aug', 9: 'Sep', 10: 'Oct', 11: 'Nov', 12: 'Dec'
})
day_df['season'] = day_df['season'].map({
    1: 'Spring', 2: 'Summer', 3: 'Fall', 4: 'Winter'
})
day_df['weathersit'] = day_df['weathersit'].map({
    1: 'Clear/Partly Cloudy',
    2: 'Misty/Cloudy',
    3: 'Light Snow/Rain',
    4: 'Heavy Rain'
})

# %%
day_df.sample(5)
# Out:
#      instant    dateday  season  year month holiday  weekday workingday  \
# 162      163 2011-06-12  Summer  2011   Jun       0        0          0
# 571      572 2012-07-25    Fall  2012   Jul       0        3          1
# 451      452 2012-03-27  Summer  2012   Mar       0        2          1
# 321      322 2011-11-18  Winter  2011   Nov       0        5          1
# 273      274 2011-10-01  Winter  2011   Oct       0        6          0
#
#               weathersit      temp     atemp       hum  windspeed  casual  \
# 162  Clear/Partly Cloudy  0.692500  0.643325  0.747917   0.163567    1467
# 571  Clear/Partly Cloudy  0.724167  0.654054  0.450000   0.164800    1383
# 451  Clear/Partly Cloudy  0.323333  0.315654  0.290000   0.187192     531
# 321  Clear/Partly Cloudy  0.274167  0.272721  0.410000   0.168533     245
# 273         Misty/Cloudy  0.410000  0.412863  0.753750   0.292296     480
#
#      registered  total_count_user   day_name
# 162        2993              4460     Sunday
# 571        6790              8173  Wednesday
# 451        4571              5102    Tuesday
# 321        3147              3392     Friday
# 273        1949              2429   Saturday

# %%
day_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   instant           731 non-null    int64
#  1   dateday           731 non-null    datetime64[ns]
#  2   season            731 non-null    category
#  3   year              731 non-null    category
#  4   month             731 non-null    category
#  5   holiday           731 non-null    category
#  6   weekday           731 non-null    int64
#  7   workingday        731 non-null    category
#  8   weathersit        731 non-null    category
#  9   temp              731 non-null    float64
#  10  atemp             731 non-null    float64
#  11  hum               731 non-null    float64
#  12  windspeed         731 non-null    float64
#  13  casual            731 non-null    int64
#  14  registered        731 non-null    int64
#  15  total_count_user  731 non-null    int64
#  16  day_name          731 non-null    object
# dtypes: category(6), datetime64[ns](1), float64(4), int64(5), object(1)
# memory usage: 68.3+ KB

# %%
# Mengubaha tipe data ke categorical
day_df['season'] = day_df.season.astype('category')
day_df['year'] = day_df.year.astype('category')
day_df['month'] = day_df.month.astype('category')
day_df['holiday'] = day_df.holiday.astype('category')
day_df['day_name'] = day_df.day_name.astype('category')
day_df['workingday'] = day_df.workingday.astype('category')
day_df['weathersit'] = day_df.weathersit.astype('category')

# %%
day_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   instant           731 non-null    int64
#  1   dateday           731 non-null    datetime64[ns]
#  2   season            731 non-null    category
#  3   year              731 non-null    category
#  4   month             731 non-null    category
#  5   holiday           731 non-null    category
#  6   weekday           731 non-null    int64
#  7   workingday        731 non-null    category
#  8   weathersit        731 non-null    category
#  9   temp              731 non-null    float64
#  10  atemp             731 non-null    float64
#  11  hum               731 non-null    float64
#  12  windspeed         731 non-null    float64
#  13  casual            731 non-null    int64
#  14  registered        731 non-null    int64
#  15  total_count_user  731 non-null    int64
#  16  day_name          731 non-null    category
# dtypes: category(7), datetime64[ns](1), float64(4), int64(5)
# memory usage: 63.7 KB

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## 1. Table day_df

# %%
#simpan data day yang telah diperbaiki
day_df.to_csv("data/real_day.csv", index=False)

rent_day_df = pd.read_csv("data/real_day.csv")
rent_day_df.head()
# Out:
#    instant     dateday  season  year month  holiday  weekday  workingday  \
# 0        1  2011-01-01  Spring  2011   Jan        0        6           0
# 1        2  2011-01-02  Spring  2011   Jan        0        0           0
# 2        3  2011-01-03  Spring  2011   Jan        0        1           1
# 3        4  2011-01-04  Spring  2011   Jan        0        2           1
# 4        5  2011-01-05  Spring  2011   Jan        0        3           1
#
#             weathersit      temp     atemp       hum  windspeed  casual  \
# 0         Misty/Cloudy  0.344167  0.363625  0.805833   0.160446     331
# 1         Misty/Cloudy  0.363478  0.353739  0.696087   0.248539     131
# 2  Clear/Partly Cloudy  0.196364  0.189405  0.437273   0.248309     120
# 3  Clear/Partly Cloudy  0.200000  0.212122  0.590435   0.160296     108
# 4  Clear/Partly Cloudy  0.226957  0.229270  0.436957   0.186900      82
#
#    registered  total_count_user   day_name
# 0         654               985   Saturday
# 1         670               801     Sunday
# 2        1229              1349     Monday
# 3        1454              1562    Tuesday
# 4        1518              1600  Wednesday

# %%
monthly_day_df = day_df.resample(rule='M', on='dateday').agg({
    "instant": "nunique",
    "casual": "sum",
    "registered": "sum",
    "total_count_user": "sum"
})
monthly_day_df.index = monthly_day_df.index.strftime('%B') #mengubah format order date menjadi Tahun-Bulan
monthly_day_df = monthly_day_df.reset_index()
monthly_day_df.rename(columns={
    "instant": "count_id",
}, inplace=True)
monthly_day_df.head()
# Out:
#     dateday  count_id  casual  registered  total_count_user
# 0   January        31    3073       35116             38189
# 1  February        28    6242       41973             48215
# 2     March        31   12826       51219             64045
# 3     April        30   22346       72524             94870
# 4       May        31   31050      104771            135821

# %%
monthly_day_df.sample(24)
# Out:
#       dateday  count_id  casual  registered  total_count_user
# 17       June        30   43294      159536            202830
# 7      August        31   28842      107849            136691
# 5        June        30   30612      112900            143512
# 1    February        28    6242       41973             48215
# 11   December        31    8448       78875             87323
# 8   September        30   26545      100873            127418
# 2       March        31   12826       51219             64045
# 19     August        31   43197      171306            214503
# 13   February        29    8721       94416            103137
# 14      March        31   31618      133257            164875
# 21    October        31   34538      164303            198841
# 4         May        31   31050      104771            135821
# 12    January        31    8969       87775             96744
# 15      April        30   38456      135768            174224
# 0     January        31    3073       35116             38189
# 16        May        31   44235      151630            195865
# 22   November        30   21009      131655            152664
# 10   November        30   15594       86573            102167
# 9     October        31   25222       98289            123511
# 20  September        30   43778      174795            218573
# 6        July        31   36452      104889            141341
# 18       July        31   41705      161902            203607
# 23   December        31   13245      110468            123713
# 3       April        30   22346       72524             94870

# %%
day_df.groupby(by=["year", "month"]).agg({
    "total_count_user": ['max', 'min', 'mean', 'sum'],
})
# Out:
# C:\Users\atsil\AppData\Local\Temp\ipykernel_45432\3038881177.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   day_df.groupby(by=["year", "month"]).agg({
#            total_count_user
#                         max   min         mean     sum
# year month
# 2011 Apr               5312   795  3162.333333   94870
#      Aug               5895  1115  4409.387097  136691
#      Dec               3940   705  2816.870968   87323
#      Feb               2927  1005  1721.964286   48215
#      Jan               1985   431  1231.903226   38189
#      Jul               6043  3285  4559.387097  141341
#      Jun               5515  3767  4783.733333  143512
#      Mar               3239   605  2065.967742   64045
#      May               5805  2633  4381.322581  135821
#      Nov               4486  1495  3405.566667  102167
#      Oct               5511   627  3984.225806  123511
#      Sep               5423  1842  4247.266667  127418
# 2012 Apr               7460  1027  5807.466667  174224
#      Aug               7865  4549  6919.451613  214503
#      Dec               6606   441  3990.741935  123713
#      Feb               5062  1529  3556.448276  103137
#      Jan               4521  1301  3120.774194   96744
#      Jul               8173  4459  6567.967742  203607
#      Jun               8120  4127  6761.000000  202830
#      Mar               8362  3194  5318.548387  164875
#      May               8294  2843  6318.225806  195865
#      Nov               6852  2277  5088.800000  152664
#      Oct               8156    22  6414.225806  198841
#      Sep               8714  4073  7285.766667  218573

# %% [markdown]
# *Dapat diperhatikan pada data ini dibedakan berdasarkan tahun dan bulan*

# %%
day_df.groupby(by="year").agg({
    "instant": "nunique",
    "casual": "sum",
    "registered": "sum",
    "total_count_user": "sum"
}).sort_values(by="year", ascending=False)
# Out:
# C:\Users\atsil\AppData\Local\Temp\ipykernel_45432\383177753.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   day_df.groupby(by="year").agg({
#       instant  casual  registered  total_count_user
# year
# 2012      366  372765     1676811           2049576
# 2011      365  247252      995851           1243103

# %% [markdown]
# *Group berdasarkan tahun*

# %%
day_df.groupby(by="weathersit").agg({
    "casual": "sum",
    "registered": "sum",
    "total_count_user": "sum"
}).sort_values(by="weathersit", ascending=False)
# Out:
# C:\Users\atsil\AppData\Local\Temp\ipykernel_45432\1138990563.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   day_df.groupby(by="weathersit").agg({
#                      casual  registered  total_count_user
# weathersit
# Misty/Cloudy         169776      827082            996858
# Light Snow/Rain        3895       33974             37869
# Clear/Partly Cloudy  446346     1811606           2257952

# %% [markdown]
# *berdasarkan cuaca*

# %%
group_by_season_day_df = day_df.groupby(by="season").agg({
    "casual": "sum",
    "registered": "sum",
    "total_count_user": "sum"
}).sort_values(by="season", ascending=False)

group_by_season_day_df
# Out:
# C:\Users\atsil\AppData\Local\Temp\ipykernel_45432\1749552967.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   group_by_season_day_df = day_df.groupby(by="season").agg({
#         casual  registered  total_count_user
# season
# Winter  129782      711831            841613
# Summer  203522      715067            918589
# Spring   60622      410726            471348
# Fall    226091      835038           1061129

# %% [markdown]
# *day_df berdasarkan season*

# %%
plt.figure(figsize=(10, 5))
colors_ = ["#D3D3D3", "#72BCD4", "#D3D3D3", "#D3D3D3"]

sns.barplot(
    y="total_count_user", 
    x="season",
    data=day_df.sort_values(by="season", ascending=False),
    palette=colors_
)
plt.title("Grafik season dan total user", loc="center", fontsize=15)
plt.ylabel(None)
plt.xlabel(None)
plt.tick_params(axis='x', labelsize=12)
plt.show()
# Out:
# C:\Users\atsil\AppData\Local\Temp\ipykernel_45432\3438813050.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
group_by_weekday_day_df = rent_day_df.groupby(by="day_name").agg({
    "casual": "sum",
    "registered": "sum",
    "total_count_user": "sum"
}).sort_values(by="day_name", ascending=True)

group_by_weekday_day_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_45432\4234839748.py in ?()
# ----> 1 group_by_weekday_day_df = rent_day_df.groupby(by="day_name").agg({
#       2     "casual": "sum",
#       3     "registered": "sum",
#       4     "total_count_user": "sum"
#
# c:\users\atsil\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py in ?(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6940             )
#    6941         elif len(by):
#    6942             # len(by) == 1
#    6943
# -> 6944             k = self._get_label_or_level_values(by[0], axis=axis)
#    6945
#    6946             # need to rewrap column in Series to apply key function
#    6947             if key is not None:
#
# c:\users\atsil\appdata\local\programs\python\python39\lib\site-packages\pandas\core\generic.py in ?(self, key, axis)
#    1840             values = self.xs(key, axis=other_axes[0])._values
#    1841         elif self._is_level_reference(key, axis=axis):
#    1842             values = self.axes[axis].get_level_values(key)._values
#    1843         else:
# -> 1844             raise KeyError(key)
#    1845
#    1846         # Check for duplicates
#    1847         if values.ndim > 1:
#
# KeyError: 'weekday'

# %%
plt.figure(figsize=(10, 5))
colors_ = ["#D3D3D3", "#72BCD4", "#D3D3D3", "#D3D3D3","#D3D3D3", "#D3D3D3","#D3D3D3"]

sns.barplot(
    y="total_count_user", 
    x="day_name",
    data=rent_day_df.sort_values(by="day_name", ascending=),
    palette=colors_
)
plt.title("Grafik hari dan total user", loc="center", fontsize=15)
plt.ylabel(None)
plt.xlabel(None)
plt.tick_params(axis='x', labelsize=12)
plt.show()
# Out:
# C:\Users\atsil\AppData\Local\Temp\ipykernel_45432\1480706322.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
